# %% [markdown]
# ## 1.Load the beans dataset.

# %%
#import tensorflow as tf
import tensorflow.compat.v2 as tf
from tensorflow.keras import datasets, layers, models
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from __future__ import absolute_import, division, print_function, unicode_literals
from collections import Counter
# Enable eager execution
tf.enable_v2_behavior()

# %% [markdown]
# ## load the dataset
#
# Please install tensorflow_datasets packages using
#
# pip install tensorflow_datasets

# %%
# %%time
import importlib

def import_or_install(library):
    try:
        importlib.import_module(library)
        print(f"{library} is already installed.")
    except ImportError:
        print(f"{library} is not installed. Installing...")
        # !pip install {library}
        print(f"{library} has been successfully installed.")

# Example usage:
libraries_to_check = ["tensorflow_datasets"]

for library in libraries_to_check:
    import_or_install(library)
# Out:
# tensorflow_datasets is already installed.
# CPU times: total: 594 ms
# Wall time: 592 ms

# %%
import tensorflow_datasets as tfds

(bn_train, bn_validation, bn_test),bn_info = tfds.load(

    name = 'beans',

    split = ['train', 'validation', 'test'],

    as_supervised = True,

    with_info = True)

print(bn_info)
# Out:
# tfds.core.DatasetInfo(
#     name='beans',
#     full_name='beans/0.1.0',
#     description="""
#     Beans is a dataset of images of beans taken in the field using smartphone
#     cameras. It consists of 3 classes: 2 disease classes and the healthy class.
#     Diseases depicted include Angular Leaf Spot and Bean Rust. Data was annotated by
#     experts from the National Crops Resources Research Institute (NaCRRI) in Uganda
#     and collected by the Makerere AI research lab.
#     """,
#     homepage='https://github.com/AI-Lab-Makerere/ibean/',
#     data_path='C:\\Users\\Daniel Carter\\tensorflow_datasets\\beans\\0.1.0',
#     file_format=tfrecord,
#     download_size=171.69 MiB,
#     dataset_size=171.63 MiB,
#     features=FeaturesDict({
#         'image': Image(shape=(500, 500, 3), dtype=uint8),
#         'label': ClassLabel(shape=(), dtype=int64, num_classes=3),
#     }),
#     supervised_keys=('image', 'label'),
#     disable_shuffling=False,
#     splits={
#         'test': <SplitInfo num_examples=128, num_shards=1>,
#         'train': <SplitInfo num_examples=1034, num_shards=2>,
#         'validation': <SplitInfo num_examples=133, num_shards=1>,
#     },
#     citation="""@ONLINE {beansdata,
#         author="Makerere AI Lab",
#         title="Bean disease dataset",
#         month="January",
#         year="2020",
#         url="https://github.com/AI-Lab-Makerere/ibean/"
#     }""",
# )

# %%
# the training dataset has features/image and label/target
for image, label in bn_train.take(1):  # example is (image, label)
  print(image.shape, label)
# Out:
# (500, 500, 3) tf.Tensor(1, shape=(), dtype=int64)

# %%
print(bn_info.features["label"].num_classes)
print(bn_info.features["label"].names)
# Out:
# 3
# ['angular_leaf_spot', 'bean_rust', 'healthy']

# %%
print(bn_info.features.shape)
print(bn_info.features.np_dtype)
print(bn_info.features['image'].shape)
print(bn_info.features['image'].np_dtype)
# Out:
# {'image': (500, 500, 3), 'label': ()}
# {'image': <class 'numpy.uint8'>, 'label': <class 'numpy.int64'>}
# (500, 500, 3)
# <class 'numpy.uint8'>

# %%
import tensorflow as tf
from tensorflow.data import Dataset

# Assuming you have a pre-loaded image dataset `image_dataset`

# Convert dataset to a NumPy array (images and labels)
data_array = tfds.as_numpy(bn_train)

for imgs, labels in data_array:
    print (imgs.shape, labels.shape)
    break
# Out:
# (500, 500, 3) ()

# %%
# Image parameters:
image_height = 500
image_width = 500
num_channels = 3 # RGB
num_classes = 3 # healthy, angular leaf spot disease, bean rust disease

# Pipeline hyperparameters:
batch_size = 32

# Let's keep the dimensions the same (no resizing for now)
# the inputs are the image, label and target size
def normalize_image(image, label, target_height = 500, target_width = 500):
    """Normalizes images: `unit8` -> `float32` and resizes images
    by keeping the aspect ratio the same without distortion."""
    image = tf.cast(image, tf.float32)/255.
    image = tf.image.resize_with_crop_or_pad(image, target_height, target_width)
    return image, label
#apply normalize_image() function to each of image avoid writing a loop
bn_train = bn_train.map(normalize_image, num_parallel_calls = tf.data.experimental.AUTOTUNE)
bn_train = bn_train.cache().shuffle(1000)
bn_train = bn_train.shuffle(bn_info.splits['train'].num_examples)
bn_train = bn_train.batch(batch_size)
bn_train = bn_train.prefetch(tf.data.experimental.AUTOTUNE)

# %% [markdown]
# Perform the similar tasks for the validation dataset

# %%
bn_validation = bn_validation.map(
    normalize_image, num_parallel_calls = tf.data.experimental.AUTOTUNE)
bn_validation = bn_validation.batch(batch_size)
bn_validation = bn_validation.cache()
bn_validation = bn_validation.prefetch(tf.data.experimental.AUTOTUNE)

bn_test = bn_test.map(
    normalize_image, num_parallel_calls = tf.data.experimental.AUTOTUNE)
bn_test = bn_test.batch(batch_size)
bn_test = bn_test.cache()
bn_test = bn_test.prefetch(tf.data.experimental.AUTOTUNE)

# %%
def return_class_labels(ds):
    """"Returns a list of class labels from a `DatasetV1Adapter` object."""
    l_labels = []
    # since we handle labels only in this funciton, we discard the first parameter that is image
    # we take out one batch that is 32 images and lables
    for _, labels in ds.take(-1):
        labels = labels.numpy()
        l_labels.append(labels[:])
    # the l_labels is a nest of list , for example [ [1, 0, 2, ...], [2,1, 1,..], ..]
    # return a single list by using list comprehension
    #[1, 0, 2, ..., 2, 1, 1, ..]
    return [item for sublist in l_labels for item in sublist]

training_labels = return_class_labels(bn_train)
print("The distribution of training labels is: ", (Counter(training_labels)))

validation_labels = return_class_labels(bn_validation)
print("The distribution of validation labels is: ", (Counter(validation_labels)))

test_labels = return_class_labels(bn_test)
print("The distribution of test labels is: ", (Counter(test_labels)))
# Out:
# The distribution of training labels is:  Counter({1: 348, 0: 345, 2: 341})
# The distribution of validation labels is:  Counter({1: 45, 2: 44, 0: 44})
# The distribution of test labels is:  Counter({0: 43, 1: 43, 2: 42})

# %%
# take out one batch that is 32 images
example = bn_train.take(1)
# each batch has two componets, image and label
# sample=(image, lable)
for sample in example:
    image, label = sample[0], sample[1]
    #convert them to np
    image = image.numpy()
    label = label.numpy()

n_cols, n_rows = 4, 4
plt.rcParams['figure.figsize'] = [n_cols*4, n_rows*4]

fig = plt.figure()
for i in range(1, n_cols*n_rows + 1):
    ax = fig.add_subplot(n_rows, n_cols,i)
    # we label the subplots using names instead of magic numbers such as 0, 1 and 2
    ax.text(5, -9, "Angular Leaf Spot" if label[i] == 0 else "Bean Rust" if label[i] == 1 else "Healthy",
            color = 'red', fontsize = 20)
    ax.imshow(image[i, :, :, :], cmap = plt.get_cmap("jet"))

# %% [markdown]
# ## Convert TensorFlow Dataset to Numpy Array to Inspect the Pixel Values

# %%
import tensorflow as tf
from tensorflow.data import Dataset


# Convert dataset to a NumPy array (images and labels)
image_array = tfds.as_numpy(bn_train)

for img in image_array:
    print (imgs.shape)
    break
# Out:
# (500, 500, 3)

# %%
img[0]
# Out:
# array([[[[0.1882353 , 0.03921569, 0.00392157],
#          [0.1882353 , 0.03921569, 0.00392157],
#          [0.1764706 , 0.03137255, 0.        ],
#          ...,
#          [0.3529412 , 0.20784314, 0.23529412],
#          [0.34509805, 0.2       , 0.22745098],
#          [0.3372549 , 0.19215687, 0.21960784]],
#
#         [[0.19607843, 0.04705882, 0.01176471],
#          [0.19607843, 0.04705882, 0.01176471],
#          [0.1882353 , 0.04313726, 0.01176471],
#          ...,
#          [0.34117648, 0.2       , 0.21568628],
#          [0.34117648, 0.19607843, 0.22352941],
#          [0.34117648, 0.2       , 0.21568628]],
#
#         [[0.1882353 , 0.03529412, 0.00784314],
#          [0.19607843, 0.04313726, 0.01568628],
#          [0.19215687, 0.03921569, 0.01960784],
#          ...,
#          [0.34117648, 0.2       , 0.20784314],
#          [0.34901962, 0.20784314, 0.22352941],
#          [0.34901962, 0.20784314, 0.21568628]],
#
#         ...,
#
#         [[0.61960787, 0.76862746, 0.6156863 ],
#          [0.6156863 , 0.7647059 , 0.6039216 ],
#          [0.62352943, 0.77254903, 0.6117647 ],
#          ...,
#          [0.5803922 , 0.7058824 , 0.5529412 ],
#          [0.54509807, 0.67058825, 0.5176471 ],
#          [0.5568628 , 0.68235296, 0.5294118 ]],
#
#         [[0.59607846, 0.74509805, 0.5921569 ],
#          [0.69803923, 0.84705883, 0.6862745 ],
#          [0.57254905, 0.73333335, 0.5686275 ],
#          ...,
#          [0.6392157 , 0.7647059 , 0.6117647 ],
#          [0.7372549 , 0.8627451 , 0.7019608 ],
#          [0.67058825, 0.79607844, 0.63529414]],
#
#         [[0.5921569 , 0.7411765 , 0.5882353 ],
#          [0.63529414, 0.78431374, 0.62352943],
#          [0.5882353 , 0.7490196 , 0.58431375],
#          ...,
#          [0.5686275 , 0.69411767, 0.5411765 ],
#          [0.6039216 , 0.7294118 , 0.5686275 ],
#          [0.5568628 , 0.68235296, 0.52156866]]],
#
#
#        [[[0.2901961 , 0.23921569, 0.21568628],
#          [0.2627451 , 0.21176471, 0.1882353 ],
#          [0.25882354, 0.2       , 0.18039216],
#          ...,
#          [0.67058825, 0.61960787, 0.58431375],
#          [0.6627451 , 0.62352943, 0.58431375],
#          [0.5764706 , 0.5372549 , 0.49803922]],
#
#         [[0.32156864, 0.27058825, 0.24705882],
#          [0.21960784, 0.16862746, 0.14509805],
#          [0.2901961 , 0.23137255, 0.21176471],
#          ...,
#          [0.6745098 , 0.62352943, 0.5882353 ],
#          [0.6862745 , 0.63529414, 0.6       ],
#          [0.6156863 , 0.5764706 , 0.5372549 ]],
#
#         [[0.37254903, 0.3137255 , 0.28627452],
#          [0.33333334, 0.27450982, 0.24705882],
#          [0.34509805, 0.28627452, 0.25882354],
#          ...,
#          [0.64705884, 0.6       , 0.5529412 ],
#          [0.654902  , 0.60784316, 0.56078434],
#          [0.6039216 , 0.5568628 , 0.50980395]],
#
#         ...,
#
#         [[0.21176471, 0.15686275, 0.15294118],
#          [0.22352941, 0.18039216, 0.17254902],
#          [0.23137255, 0.19215687, 0.18431373],
#          ...,
#          [0.09803922, 0.10196079, 0.07058824],
#          [0.08627451, 0.09019608, 0.05882353],
#          [0.10588235, 0.10980392, 0.07843138]],
#
#         [[0.1764706 , 0.13333334, 0.1254902 ],
#          [0.1764706 , 0.13725491, 0.12941177],
#          [0.19215687, 0.15294118, 0.14509805],
#          ...,
#          [0.12156863, 0.1254902 , 0.09411765],
#          [0.09411765, 0.09803922, 0.06666667],
#          [0.09411765, 0.09803922, 0.06666667]],
#
#         [[0.19607843, 0.15686275, 0.14901961],
#          [0.16470589, 0.1254902 , 0.11764706],
#          [0.16862746, 0.13725491, 0.1254902 ],
#          ...,
#          [0.13725491, 0.14117648, 0.10980392],
#          [0.09803922, 0.10196079, 0.07058824],
#          [0.09019608, 0.09411765, 0.0627451 ]]],
#
#
#        [[[0.3764706 , 0.4509804 , 0.19215687],
#          [0.34901962, 0.4117647 , 0.16470589],
#          [0.34509805, 0.37254903, 0.16862746],
#          ...,
#          [0.1764706 , 0.36078432, 0.04313726],
#          [0.1882353 , 0.3647059 , 0.03137255],
#          [0.18039216, 0.36078432, 0.01568628]],
#
#         [[0.44313726, 0.5058824 , 0.25882354],
#          [0.37254903, 0.42745098, 0.1882353 ],
#          [0.4117647 , 0.4392157 , 0.23529412],
#          ...,
#          [0.19607843, 0.36862746, 0.05882353],
#          [0.16470589, 0.33333334, 0.01176471],
#          [0.18431373, 0.35686275, 0.02352941]],
#
#         [[0.4392157 , 0.49411765, 0.2627451 ],
#          [0.42352942, 0.46666667, 0.24705882],
#          [0.42745098, 0.44313726, 0.24313726],
#          ...,
#          [0.19607843, 0.36078432, 0.0627451 ],
#          [0.18431373, 0.34509805, 0.03921569],
#          [0.18039216, 0.34117648, 0.03137255]],
#
#         ...,
#
#         [[0.4862745 , 0.32156864, 0.36078432],
#          [0.5411765 , 0.3764706 , 0.41568628],
#          [0.5764706 , 0.4117647 , 0.45882353],
#          ...,
#          [0.12156863, 0.1254902 , 0.05490196],
#          [0.10980392, 0.11372549, 0.04313726],
#          [0.09411765, 0.09803922, 0.02745098]],
#
#         [[0.5529412 , 0.3882353 , 0.42745098],
#          [0.5176471 , 0.3529412 , 0.39215687],
#          [0.52156866, 0.35686275, 0.40392157],
#          ...,
#          [0.11372549, 0.12156863, 0.03921569],
#          [0.09803922, 0.10588235, 0.02352941],
#          [0.09019608, 0.09803922, 0.01568628]],
#
#         [[0.54901963, 0.38431373, 0.42352942],
#          [0.5294118 , 0.3647059 , 0.40392157],
#          [0.5372549 , 0.37254903, 0.41960785],
#          ...,
#          [0.10588235, 0.11372549, 0.03137255],
#          [0.09411765, 0.10196079, 0.01960784],
#          [0.09411765, 0.10196079, 0.01960784]]],
#
#
#        ...,
#
#
#        [[[0.57254905, 0.30980393, 0.2784314 ],
#          [0.54901963, 0.28627452, 0.25490198],
#          [0.5529412 , 0.3019608 , 0.26666668],
#          ...,
#          [0.29803923, 0.36078432, 0.18431373],
#          [0.2901961 , 0.3529412 , 0.1764706 ],
#          [0.27058825, 0.33333334, 0.15686275]],
#
#         [[0.5568628 , 0.29411766, 0.2627451 ],
#          [0.5294118 , 0.2784314 , 0.24313726],
#          [0.5137255 , 0.2627451 , 0.22745098],
#          ...,
#          [0.28235295, 0.34509805, 0.16862746],
#          [0.28235295, 0.33333334, 0.16078432],
#          [0.25490198, 0.31764707, 0.14117648]],
#
#         [[0.5294118 , 0.2784314 , 0.24313726],
#          [0.5176471 , 0.26666668, 0.23137255],
#          [0.49019608, 0.24313726, 0.21568628],
#          ...,
#          [0.2901961 , 0.34117648, 0.16862746],
#          [0.27450982, 0.31764707, 0.14901961],
#          [0.24705882, 0.29803923, 0.1254902 ]],
#
#         ...,
#
#         [[0.14901961, 0.        , 0.        ],
#          [0.15294118, 0.        , 0.00392157],
#          [0.15294118, 0.        , 0.00392157],
#          ...,
#          [0.47843137, 0.27058825, 0.34117648],
#          [0.54901963, 0.3254902 , 0.4       ],
#          [0.6       , 0.3764706 , 0.4509804 ]],
#
#         [[0.14901961, 0.        , 0.        ],
#          [0.14901961, 0.        , 0.        ],
#          [0.15294118, 0.        , 0.00392157],
#          ...,
#          [0.44705883, 0.23921569, 0.30980393],
#          [0.53333336, 0.30980393, 0.38431373],
#          [0.5764706 , 0.3529412 , 0.42745098]],
#
#         [[0.14901961, 0.        , 0.        ],
#          [0.14901961, 0.        , 0.        ],
#          [0.15294118, 0.        , 0.00392157],
#          ...,
#          [0.43137255, 0.22352941, 0.29411766],
#          [0.5176471 , 0.29411766, 0.36862746],
#          [0.54901963, 0.3254902 , 0.4       ]]],
#
#
#        [[[0.32941177, 0.35686275, 0.14509805],
#          [0.3137255 , 0.34509805, 0.12156863],
#          [0.35686275, 0.3764706 , 0.15686275],
#          ...,
#          [0.53333336, 0.6       , 0.2       ],
#          [0.57254905, 0.6431373 , 0.21960784],
#          [0.61960787, 0.6901961 , 0.2509804 ]],
#
#         [[0.3372549 , 0.37254903, 0.14901961],
#          [0.37254903, 0.40784314, 0.18431373],
#          [0.39215687, 0.42352942, 0.19215687],
#          ...,
#          [0.58431375, 0.654902  , 0.23137255],
#          [0.6313726 , 0.69803923, 0.24705882],
#          [0.6784314 , 0.75686276, 0.27450982]],
#
#         [[0.37254903, 0.42745098, 0.1882353 ],
#          [0.3882353 , 0.44313726, 0.2       ],
#          [0.4       , 0.44705883, 0.20392157],
#          ...,
#          [0.627451  , 0.69803923, 0.22745098],
#          [0.6784314 , 0.74509805, 0.22745098],
#          [0.70980394, 0.7921569 , 0.23921569]],
#
#         ...,
#
#         [[0.54509807, 0.5372549 , 0.34509805],
#          [0.5568628 , 0.5568628 , 0.36078432],
#          [0.5372549 , 0.54509807, 0.3529412 ],
#          ...,
#          [0.02745098, 0.07450981, 0.        ],
#          [0.02352941, 0.07058824, 0.        ],
#          [0.02745098, 0.07450981, 0.        ]],
#
#         [[0.5176471 , 0.5176471 , 0.32156864],
#          [0.52156866, 0.5294118 , 0.33333334],
#          [0.5137255 , 0.5294118 , 0.33333334],
#          ...,
#          [0.03137255, 0.06666667, 0.        ],
#          [0.02745098, 0.0627451 , 0.        ],
#          [0.02745098, 0.0627451 , 0.        ]],
#
#         [[0.49411765, 0.5019608 , 0.30588236],
#          [0.47843137, 0.49411765, 0.29411766],
#          [0.47843137, 0.49411765, 0.29803923],
#          ...,
#          [0.03137255, 0.06666667, 0.        ],
#          [0.02352941, 0.05882353, 0.        ],
#          [0.02352941, 0.05882353, 0.        ]]],
#
#
#        [[[0.31764707, 0.21568628, 0.07843138],
#          [0.30980393, 0.20784314, 0.07058824],
#          [0.29803923, 0.2       , 0.07843138],
#          ...,
#          [0.40392157, 0.4509804 , 0.30980393],
#          [0.3647059 , 0.3882353 , 0.25490198],
#          [0.30980393, 0.3137255 , 0.18039216]],
#
#         [[0.30588236, 0.20392157, 0.07450981],
#          [0.28627452, 0.18431373, 0.05490196],
#          [0.26666668, 0.16862746, 0.04705882],
#          ...,
#          [0.36862746, 0.41568628, 0.27450982],
#          [0.3647059 , 0.38039216, 0.2509804 ],
#          [0.26666668, 0.26666668, 0.13333334]],
#
#         [[0.29803923, 0.19215687, 0.07450981],
#          [0.2784314 , 0.17254902, 0.05490196],
#          [0.2627451 , 0.15686275, 0.03921569],
#          ...,
#          [0.34509805, 0.37254903, 0.23921569],
#          [0.32156864, 0.31764707, 0.19607843],
#          [0.2509804 , 0.23921569, 0.10980392]],
#
#         ...,
#
#         [[0.32941177, 0.5529412 , 0.18039216],
#          [0.3529412 , 0.5647059 , 0.18039216],
#          [0.44313726, 0.63529414, 0.22352941],
#          ...,
#          [0.02352941, 0.01960784, 0.00392157],
#          [0.02352941, 0.01960784, 0.00392157],
#          [0.02352941, 0.01960784, 0.00392157]],
#
#         [[0.36078432, 0.5764706 , 0.20784314],
#          [0.36078432, 0.57254905, 0.1882353 ],
#          [0.45490196, 0.64705884, 0.23529412],
#          ...,
#          [0.01568628, 0.01176471, 0.        ],
#          [0.01568628, 0.01176471, 0.        ],
#          [0.01960784, 0.01568628, 0.        ]],
#
#         [[0.33333334, 0.54901963, 0.18039216],
#          [0.3882353 , 0.6       , 0.21568628],
#          [0.35686275, 0.54901963, 0.13725491],
#          ...,
#          [0.01176471, 0.00784314, 0.        ],
#          [0.01568628, 0.01176471, 0.        ],
#          [0.01568628, 0.01176471, 0.        ]]]], dtype=float32)

# %%
print(f'The maximum value of pixels = {np.amax(img[0])}; the minimum value of pixels ={np.amin(img[0])}' )
# Out:
# The maximum value of pixels = 1.0; the minimum value of pixels =0.0

# %%
input_shape =imgs.shape
input_shape
# Out:
# (500, 500, 3)

# %%
model = models.Sequential()
# Get the image size using codes instead of using magic number (32,32,3)
input_shape =imgs.shape
print(f'The input shape = {input_shape}')
# The first Convolution layer has 32 filters, with the output has 32 channels. The size of the filter is 3*3
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape= input_shape))
# Followed by 2*2 pooling window 
model.add(layers.MaxPooling2D((2, 2)))
# The second Convolution layer has 64 filters, with the output has 64 channels. The size of the filter is 3*3
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
# Followed by 2*2 pooling window 
model.add(layers.MaxPooling2D((2, 2)))
# The second Convolution layer has 64 filters, with the output has 64 channels. The size of the filter is 3*3
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
# The Third Convolution layer has 64 filters, with the output has 64 channels. The size of the filter is 2*2
model.add(layers.Conv2D(64, (2, 2), activation='relu'))
# Out:
# The input shape = (500, 500, 3)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 498, 498, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 249, 249, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 247, 247, 64)      18496
#
#  max_pooling2d_1 (MaxPooling  (None, 123, 123, 64)     0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 121, 121, 64)      36928
#
#  conv2d_3 (Conv2D)           (None, 120, 120, 64)      16448
#
# =================================================================
# Total params: 72,768
# Trainable params: 72,768
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Convert  feature matrix from 4D to 2D
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
# Add dropout layer
model.add(layers.Dropout(0.2))
# Last layer must have 3 neuron to match the label
model.add(layers.Dense(3))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 498, 498, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 249, 249, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 247, 247, 64)      18496
#
#  max_pooling2d_1 (MaxPooling  (None, 123, 123, 64)     0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 121, 121, 64)      36928
#
#  conv2d_3 (Conv2D)           (None, 120, 120, 64)      16448
#
#  flatten (Flatten)           (None, 921600)            0
#
#  dense (Dense)               (None, 64)                58982464
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 59,055,427
# Trainable params: 59,055,427
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# %%time
callback = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience= 3)
history = model.fit(bn_train, epochs=20, 
                    validation_data=(bn_validation), callbacks=[callback], verbose = 1)
# Out:
# Epoch 1/20
# 33/33 [==============================] - 82s 2s/step - loss: 2.5595 - accuracy: 0.4159 - val_loss: 0.9266 - val_accuracy: 0.5564
# Epoch 2/20
# 33/33 [==============================] - 80s 2s/step - loss: 0.9165 - accuracy: 0.5735 - val_loss: 0.8325 - val_accuracy: 0.5940
# Epoch 3/20
# 33/33 [==============================] - 82s 2s/step - loss: 0.7972 - accuracy: 0.6315 - val_loss: 0.6943 - val_accuracy: 0.6617
# Epoch 4/20
# 33/33 [==============================] - 84s 3s/step - loss: 0.7592 - accuracy: 0.6838 - val_loss: 0.7888 - val_accuracy: 0.6015
# Epoch 5/20
# 33/33 [==============================] - 86s 3s/step - loss: 0.6930 - accuracy: 0.6847 - val_loss: 0.7102 - val_accuracy: 0.6391
# Epoch 6/20
# 33/33 [==============================] - 92s 3s/step - loss: 0.6132 - accuracy: 0.7379 - val_loss: 0.6546 - val_accuracy: 0.7368
# Epoch 7/20
# 33/33 [==============================] - 89s 3s/step - loss: 0.5952 - accuracy: 0.7485 - val_loss: 0.6061 - val_accuracy: 0.7368
# Epoch 8/20
# 33/33 [==============================] - 87s 3s/step - loss: 0.5572 - accuracy: 0.7737 - val_loss: 0.5650 - val_accuracy: 0.7970
# Epoch 9/20
# 33/33 [==============================] - 82s 2s/step - loss: 0.4659 - accuracy: 0.8298 - val_loss: 0.6440 - val_accuracy: 0.7368
# Epoch 10/20
# 33/33 [==============================] - 82s 2s/step - loss: 0.3841 - accuracy: 0.8443 - val_loss: 0.7064 - val_accuracy: 0.7368
# Epoch 11/20
# 33/33 [==============================] - 82s 3s/step - loss: 0.3688 - accuracy: 0.8482 - val_loss: 0.7650 - val_accuracy: 0.7594
# CPU times: total: 3h 50min 25s
# Wall time: 15min 28s

# %%
## Evaluate the Model
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

train_history = pd.DataFrame(history.history)
train_history['epoch'] = history.epoch
# Plot train loss
sns.lineplot(x='epoch', y ='loss', data =train_history)
# Plot validation loss
sns.lineplot(x='epoch', y ='val_loss', data =train_history)
# Add legends
plt.legend(labels=['train_loss', 'val_loss'])

# %%
sns.lineplot(x='epoch', y ='accuracy', data =train_history)
# Plot validation loss
sns.lineplot(x='epoch', y ='val_accuracy', data =train_history)
# Add legends
plt.legend(labels=['train_accuracy', 'val_accuracy'])

# %% [markdown]
# ## Overfit or Underfit?
#
# I believe that the model is overfitting because it is unable to generalize based on the graph results

# %%
data_aug = tf.keras.Sequential(
  [
    tf.keras.layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical", 
                                                 input_shape=(image_height, 
                                                              image_width,
                                                              num_channels)),
    tf.keras.layers.experimental.preprocessing.RandomRotation(0.1),
    tf.keras.layers.experimental.preprocessing.RandomTranslation(height_factor=0.1,width_factor = 0.1 ),
    tf.keras.layers.experimental.preprocessing.RandomZoom(height_factor=(0.1, 0.1))
  ]
)

# %%
model = tf.keras.Sequential([
  # Data augmentation
  data_aug,
  # Data normalization
  tf.keras.layers.experimental.preprocessing.Rescaling(1./255),
  tf.keras.layers.Conv2D(32, (3,3), padding='same', activation='relu'),
  tf.keras.layers.MaxPooling2D((2,2)),
  tf.keras.layers.Conv2D(64, (3,3), padding='same', activation='relu'),
  tf.keras.layers.MaxPooling2D((2,2)),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(64, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(3)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_1 (Sequential)   (None, 500, 500, 3)       0
#
#  rescaling (Rescaling)       (None, 500, 500, 3)       0
#
#  conv2d_4 (Conv2D)           (None, 500, 500, 32)      896
#
#  max_pooling2d_2 (MaxPooling  (None, 250, 250, 32)     0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 250, 250, 64)      18496
#
#  max_pooling2d_3 (MaxPooling  (None, 125, 125, 64)     0
#  2D)
#
#  dropout_1 (Dropout)         (None, 125, 125, 64)      0
#
#  flatten_1 (Flatten)         (None, 1000000)           0
#
#  dense_2 (Dense)             (None, 64)                64000064
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 64,019,651
# Trainable params: 64,019,651
# Non-trainable params: 0
# _________________________________________________________________

# %%
# %%time
callback = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience= 3)
history = model.fit(bn_train, epochs=20, 
                    validation_data=(bn_validation), callbacks=[callback], verbose = 1)
# Out:
# Epoch 1/20
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# 33/33 [==============================] - 85s 2s/step - loss: 1.1030 - accuracy: 0.3356 - val_loss: 1.0986 - val_accuracy: 0.3308
# Epoch 2/20
# 33/33 [==============================] - 78s 2s/step - loss: 1.0988 - accuracy: 0.3211 - val_loss: 1.0986 - val_accuracy: 0.3383
# Epoch 3/20
# 33/33 [==============================] - 78s 2s/step - loss: 1.0986 - accuracy: 0.3221 - val_loss: 1.0986 - val_accuracy: 0.3308
# Epoch 4/20
# 33/33 [==============================] - 77s 2s/step - loss: 1.0987 - accuracy: 0.3259 - val_loss: 1.0986 - val_accuracy: 0.3383
# Epoch 5/20
# 33/33 [==============================] - 76s 2s/step - loss: 1.0987 - accuracy: 0.3279 - val_loss: 1.0986 - val_accuracy: 0.3308
# CPU times: total: 1h 37min 31s
# Wall time: 6min 33s

# %%
train_history = pd.DataFrame(history.history)
train_history['epoch'] = history.epoch
# Plot train loss
sns.lineplot(x='epoch', y ='loss', data =train_history)
# Plot validation loss
sns.lineplot(x='epoch', y ='val_loss', data =train_history)
# Add legends
plt.legend(labels=['train_loss', 'val_loss'])

# %%
sns.lineplot(x='epoch', y ='accuracy', data =train_history)
# Plot validation loss
sns.lineplot(x='epoch', y ='val_accuracy', data =train_history)
# Add legends
plt.legend(labels=['train_accuracy', 'val_accuracy'])

# %% [markdown]
# ### Better?
#
# As you can see from the graphs, data augmentation did not help here. I think I probably did something wrong in implementing it

# %%
IMG_SHAPE = (image_height, image_width, num_channels)

MobileNetV3Large_model = tf.keras.applications.MobileNetV3Large(input_shape = IMG_SHAPE,
                                               include_top=False, # Remove the fully-connected layer
                                               weights='imagenet') # Pre-training on ImageNet
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v3/weights_mobilenet_v3_large_224_1.0_float_no_top_v2.h5
# 12683000/12683000 [==============================] - 1s 0us/step

# %%
MobileNetV3Large_model.summary()
# Out:
# Model: "MobilenetV3large"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 500, 500, 3  0           []
#                                 )]
#
#  rescaling_1 (Rescaling)        (None, 500, 500, 3)  0           ['input_1[0][0]']
#
#  Conv (Conv2D)                  (None, 250, 250, 16  432         ['rescaling_1[0][0]']
#                                 )
#
#  Conv/BatchNorm (BatchNormaliza  (None, 250, 250, 16  64         ['Conv[0][0]']
#  tion)                          )
#
#  tf.__operators__.add (TFOpLamb  (None, 250, 250, 16  0          ['Conv/BatchNorm[0][0]']
#  da)                            )
#
#  re_lu (ReLU)                   (None, 250, 250, 16  0           ['tf.__operators__.add[0][0]']
#                                 )
#
#  tf.math.multiply (TFOpLambda)  (None, 250, 250, 16  0           ['re_lu[0][0]']
#                                 )
#
#  multiply (Multiply)            (None, 250, 250, 16  0           ['Conv/BatchNorm[0][0]',
#                                 )                                 'tf.math.multiply[0][0]']
#
#  expanded_conv/depthwise (Depth  (None, 250, 250, 16  144        ['multiply[0][0]']
#  wiseConv2D)                    )
#
#  expanded_conv/depthwise/BatchN  (None, 250, 250, 16  64         ['expanded_conv/depthwise[0][0]']
#  orm (BatchNormalization)       )
#
#  re_lu_1 (ReLU)                 (None, 250, 250, 16  0           ['expanded_conv/depthwise/BatchNo
#                                 )                                rm[0][0]']
#
#  expanded_conv/project (Conv2D)  (None, 250, 250, 16  256        ['re_lu_1[0][0]']
#                                 )
#
#  expanded_conv/project/BatchNor  (None, 250, 250, 16  64         ['expanded_conv/project[0][0]']
#  m (BatchNormalization)         )
#
#  expanded_conv/Add (Add)        (None, 250, 250, 16  0           ['multiply[0][0]',
#                                 )                                 'expanded_conv/project/BatchNorm
#                                                                  [0][0]']
#
#  expanded_conv_1/expand (Conv2D  (None, 250, 250, 64  1024       ['expanded_conv/Add[0][0]']
#  )                              )
#
#  expanded_conv_1/expand/BatchNo  (None, 250, 250, 64  256        ['expanded_conv_1/expand[0][0]']
#  rm (BatchNormalization)        )
#
#  re_lu_2 (ReLU)                 (None, 250, 250, 64  0           ['expanded_conv_1/expand/BatchNor
#                                 )                                m[0][0]']
#
#  expanded_conv_1/depthwise/pad   (None, 251, 251, 64  0          ['re_lu_2[0][0]']
#  (ZeroPadding2D)                )
#
#  expanded_conv_1/depthwise (Dep  (None, 125, 125, 64  576        ['expanded_conv_1/depthwise/pad[0
#  thwiseConv2D)                  )                                ][0]']
#
#  expanded_conv_1/depthwise/Batc  (None, 125, 125, 64  256        ['expanded_conv_1/depthwise[0][0]
#  hNorm (BatchNormalization)     )                                ']
#
#  re_lu_3 (ReLU)                 (None, 125, 125, 64  0           ['expanded_conv_1/depthwise/Batch
#                                 )                                Norm[0][0]']
#
#  expanded_conv_1/project (Conv2  (None, 125, 125, 24  1536       ['re_lu_3[0][0]']
#  D)                             )
#
#  expanded_conv_1/project/BatchN  (None, 125, 125, 24  96         ['expanded_conv_1/project[0][0]']
#  orm (BatchNormalization)       )
#
#  expanded_conv_2/expand (Conv2D  (None, 125, 125, 72  1728       ['expanded_conv_1/project/BatchNo
#  )                              )                                rm[0][0]']
#
#  expanded_conv_2/expand/BatchNo  (None, 125, 125, 72  288        ['expanded_conv_2/expand[0][0]']
#  rm (BatchNormalization)        )
#
#  re_lu_4 (ReLU)                 (None, 125, 125, 72  0           ['expanded_conv_2/expand/BatchNor
#                                 )                                m[0][0]']
#
#  expanded_conv_2/depthwise (Dep  (None, 125, 125, 72  648        ['re_lu_4[0][0]']
#  thwiseConv2D)                  )
#
#  expanded_conv_2/depthwise/Batc  (None, 125, 125, 72  288        ['expanded_conv_2/depthwise[0][0]
#  hNorm (BatchNormalization)     )                                ']
#
#  re_lu_5 (ReLU)                 (None, 125, 125, 72  0           ['expanded_conv_2/depthwise/Batch
#                                 )                                Norm[0][0]']
#
#  expanded_conv_2/project (Conv2  (None, 125, 125, 24  1728       ['re_lu_5[0][0]']
#  D)                             )
#
#  expanded_conv_2/project/BatchN  (None, 125, 125, 24  96         ['expanded_conv_2/project[0][0]']
#  orm (BatchNormalization)       )
#
#  expanded_conv_2/Add (Add)      (None, 125, 125, 24  0           ['expanded_conv_1/project/BatchNo
#                                 )                                rm[0][0]',
#                                                                   'expanded_conv_2/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_3/expand (Conv2D  (None, 125, 125, 72  1728       ['expanded_conv_2/Add[0][0]']
#  )                              )
#
#  expanded_conv_3/expand/BatchNo  (None, 125, 125, 72  288        ['expanded_conv_3/expand[0][0]']
#  rm (BatchNormalization)        )
#
#  re_lu_6 (ReLU)                 (None, 125, 125, 72  0           ['expanded_conv_3/expand/BatchNor
#                                 )                                m[0][0]']
#
#  expanded_conv_3/depthwise/pad   (None, 129, 129, 72  0          ['re_lu_6[0][0]']
#  (ZeroPadding2D)                )
#
#  expanded_conv_3/depthwise (Dep  (None, 63, 63, 72)  1800        ['expanded_conv_3/depthwise/pad[0
#  thwiseConv2D)                                                   ][0]']
#
#  expanded_conv_3/depthwise/Batc  (None, 63, 63, 72)  288         ['expanded_conv_3/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_7 (ReLU)                 (None, 63, 63, 72)   0           ['expanded_conv_3/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 72)    0           ['re_lu_7[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 24)    1752        ['expanded_conv_3/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 24)    0           ['expanded_conv_3/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 72)    1800        ['expanded_conv_3/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, 1, 1, 72)    0           ['expanded_conv_3/squeeze_excite/
#  mbda)                                                           Conv_1[0][0]']
#
#  re_lu_8 (ReLU)                 (None, 1, 1, 72)     0           ['tf.__operators__.add_1[0][0]']
#
#  tf.math.multiply_1 (TFOpLambda  (None, 1, 1, 72)    0           ['re_lu_8[0][0]']
#  )
#
#  expanded_conv_3/squeeze_excite  (None, 63, 63, 72)  0           ['re_lu_7[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_1[0][0]']
#
#  expanded_conv_3/project (Conv2  (None, 63, 63, 40)  2880        ['expanded_conv_3/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_3/project/BatchN  (None, 63, 63, 40)  160         ['expanded_conv_3/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_4/expand (Conv2D  (None, 63, 63, 120)  4800       ['expanded_conv_3/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_4/expand/BatchNo  (None, 63, 63, 120)  480        ['expanded_conv_4/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_9 (ReLU)                 (None, 63, 63, 120)  0           ['expanded_conv_4/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_4/depthwise (Dep  (None, 63, 63, 120)  3000       ['re_lu_9[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_4/depthwise/Batc  (None, 63, 63, 120)  480        ['expanded_conv_4/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_10 (ReLU)                (None, 63, 63, 120)  0           ['expanded_conv_4/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 120)   0           ['re_lu_10[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 32)    3872        ['expanded_conv_4/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 32)    0           ['expanded_conv_4/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 120)   3960        ['expanded_conv_4/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_2 (TFOpLa  (None, 1, 1, 120)   0           ['expanded_conv_4/squeeze_excite/
#  mbda)                                                           Conv_1[0][0]']
#
#  re_lu_11 (ReLU)                (None, 1, 1, 120)    0           ['tf.__operators__.add_2[0][0]']
#
#  tf.math.multiply_2 (TFOpLambda  (None, 1, 1, 120)   0           ['re_lu_11[0][0]']
#  )
#
#  expanded_conv_4/squeeze_excite  (None, 63, 63, 120)  0          ['re_lu_10[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_2[0][0]']
#
#  expanded_conv_4/project (Conv2  (None, 63, 63, 40)  4800        ['expanded_conv_4/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_4/project/BatchN  (None, 63, 63, 40)  160         ['expanded_conv_4/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_4/Add (Add)      (None, 63, 63, 40)   0           ['expanded_conv_3/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_4/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_5/expand (Conv2D  (None, 63, 63, 120)  4800       ['expanded_conv_4/Add[0][0]']
#  )
#
#  expanded_conv_5/expand/BatchNo  (None, 63, 63, 120)  480        ['expanded_conv_5/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_12 (ReLU)                (None, 63, 63, 120)  0           ['expanded_conv_5/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_5/depthwise (Dep  (None, 63, 63, 120)  3000       ['re_lu_12[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_5/depthwise/Batc  (None, 63, 63, 120)  480        ['expanded_conv_5/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_13 (ReLU)                (None, 63, 63, 120)  0           ['expanded_conv_5/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 120)   0           ['re_lu_13[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 32)    3872        ['expanded_conv_5/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 32)    0           ['expanded_conv_5/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 120)   3960        ['expanded_conv_5/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_3 (TFOpLa  (None, 1, 1, 120)   0           ['expanded_conv_5/squeeze_excite/
#  mbda)                                                           Conv_1[0][0]']
#
#  re_lu_14 (ReLU)                (None, 1, 1, 120)    0           ['tf.__operators__.add_3[0][0]']
#
#  tf.math.multiply_3 (TFOpLambda  (None, 1, 1, 120)   0           ['re_lu_14[0][0]']
#  )
#
#  expanded_conv_5/squeeze_excite  (None, 63, 63, 120)  0          ['re_lu_13[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_3[0][0]']
#
#  expanded_conv_5/project (Conv2  (None, 63, 63, 40)  4800        ['expanded_conv_5/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_5/project/BatchN  (None, 63, 63, 40)  160         ['expanded_conv_5/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_5/Add (Add)      (None, 63, 63, 40)   0           ['expanded_conv_4/Add[0][0]',
#                                                                   'expanded_conv_5/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_6/expand (Conv2D  (None, 63, 63, 240)  9600       ['expanded_conv_5/Add[0][0]']
#  )
#
#  expanded_conv_6/expand/BatchNo  (None, 63, 63, 240)  960        ['expanded_conv_6/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_4 (TFOpLa  (None, 63, 63, 240)  0          ['expanded_conv_6/expand/BatchNor
#  mbda)                                                           m[0][0]']
#
#  re_lu_15 (ReLU)                (None, 63, 63, 240)  0           ['tf.__operators__.add_4[0][0]']
#
#  tf.math.multiply_4 (TFOpLambda  (None, 63, 63, 240)  0          ['re_lu_15[0][0]']
#  )
#
#  multiply_1 (Multiply)          (None, 63, 63, 240)  0           ['expanded_conv_6/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_4[0][0]']
#
#  expanded_conv_6/depthwise/pad   (None, 65, 65, 240)  0          ['multiply_1[0][0]']
#  (ZeroPadding2D)
#
#  expanded_conv_6/depthwise (Dep  (None, 32, 32, 240)  2160       ['expanded_conv_6/depthwise/pad[0
#  thwiseConv2D)                                                   ][0]']
#
#  expanded_conv_6/depthwise/Batc  (None, 32, 32, 240)  960        ['expanded_conv_6/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_5 (TFOpLa  (None, 32, 32, 240)  0          ['expanded_conv_6/depthwise/Batch
#  mbda)                                                           Norm[0][0]']
#
#  re_lu_16 (ReLU)                (None, 32, 32, 240)  0           ['tf.__operators__.add_5[0][0]']
#
#  tf.math.multiply_5 (TFOpLambda  (None, 32, 32, 240)  0          ['re_lu_16[0][0]']
#  )
#
#  multiply_2 (Multiply)          (None, 32, 32, 240)  0           ['expanded_conv_6/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_5[0][0]']
#
#  expanded_conv_6/project (Conv2  (None, 32, 32, 80)  19200       ['multiply_2[0][0]']
#  D)
#
#  expanded_conv_6/project/BatchN  (None, 32, 32, 80)  320         ['expanded_conv_6/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_7/expand (Conv2D  (None, 32, 32, 200)  16000      ['expanded_conv_6/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_7/expand/BatchNo  (None, 32, 32, 200)  800        ['expanded_conv_7/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_6 (TFOpLa  (None, 32, 32, 200)  0          ['expanded_conv_7/expand/BatchNor
#  mbda)                                                           m[0][0]']
#
#  re_lu_17 (ReLU)                (None, 32, 32, 200)  0           ['tf.__operators__.add_6[0][0]']
#
#  tf.math.multiply_6 (TFOpLambda  (None, 32, 32, 200)  0          ['re_lu_17[0][0]']
#  )
#
#  multiply_3 (Multiply)          (None, 32, 32, 200)  0           ['expanded_conv_7/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_6[0][0]']
#
#  expanded_conv_7/depthwise (Dep  (None, 32, 32, 200)  1800       ['multiply_3[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_7/depthwise/Batc  (None, 32, 32, 200)  800        ['expanded_conv_7/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_7 (TFOpLa  (None, 32, 32, 200)  0          ['expanded_conv_7/depthwise/Batch
#  mbda)                                                           Norm[0][0]']
#
#  re_lu_18 (ReLU)                (None, 32, 32, 200)  0           ['tf.__operators__.add_7[0][0]']
#
#  tf.math.multiply_7 (TFOpLambda  (None, 32, 32, 200)  0          ['re_lu_18[0][0]']
#  )
#
#  multiply_4 (Multiply)          (None, 32, 32, 200)  0           ['expanded_conv_7/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_7[0][0]']
#
#  expanded_conv_7/project (Conv2  (None, 32, 32, 80)  16000       ['multiply_4[0][0]']
#  D)
#
#  expanded_conv_7/project/BatchN  (None, 32, 32, 80)  320         ['expanded_conv_7/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_7/Add (Add)      (None, 32, 32, 80)   0           ['expanded_conv_6/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_7/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_8/expand (Conv2D  (None, 32, 32, 184)  14720      ['expanded_conv_7/Add[0][0]']
#  )
#
#  expanded_conv_8/expand/BatchNo  (None, 32, 32, 184)  736        ['expanded_conv_8/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_8 (TFOpLa  (None, 32, 32, 184)  0          ['expanded_conv_8/expand/BatchNor
#  mbda)                                                           m[0][0]']
#
#  re_lu_19 (ReLU)                (None, 32, 32, 184)  0           ['tf.__operators__.add_8[0][0]']
#
#  tf.math.multiply_8 (TFOpLambda  (None, 32, 32, 184)  0          ['re_lu_19[0][0]']
#  )
#
#  multiply_5 (Multiply)          (None, 32, 32, 184)  0           ['expanded_conv_8/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_8[0][0]']
#
#  expanded_conv_8/depthwise (Dep  (None, 32, 32, 184)  1656       ['multiply_5[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_8/depthwise/Batc  (None, 32, 32, 184)  736        ['expanded_conv_8/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_9 (TFOpLa  (None, 32, 32, 184)  0          ['expanded_conv_8/depthwise/Batch
#  mbda)                                                           Norm[0][0]']
#
#  re_lu_20 (ReLU)                (None, 32, 32, 184)  0           ['tf.__operators__.add_9[0][0]']
#
#  tf.math.multiply_9 (TFOpLambda  (None, 32, 32, 184)  0          ['re_lu_20[0][0]']
#  )
#
#  multiply_6 (Multiply)          (None, 32, 32, 184)  0           ['expanded_conv_8/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_9[0][0]']
#
#  expanded_conv_8/project (Conv2  (None, 32, 32, 80)  14720       ['multiply_6[0][0]']
#  D)
#
#  expanded_conv_8/project/BatchN  (None, 32, 32, 80)  320         ['expanded_conv_8/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_8/Add (Add)      (None, 32, 32, 80)   0           ['expanded_conv_7/Add[0][0]',
#                                                                   'expanded_conv_8/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_9/expand (Conv2D  (None, 32, 32, 184)  14720      ['expanded_conv_8/Add[0][0]']
#  )
#
#  expanded_conv_9/expand/BatchNo  (None, 32, 32, 184)  736        ['expanded_conv_9/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_10 (TFOpL  (None, 32, 32, 184)  0          ['expanded_conv_9/expand/BatchNor
#  ambda)                                                          m[0][0]']
#
#  re_lu_21 (ReLU)                (None, 32, 32, 184)  0           ['tf.__operators__.add_10[0][0]']
#
#  tf.math.multiply_10 (TFOpLambd  (None, 32, 32, 184)  0          ['re_lu_21[0][0]']
#  a)
#
#  multiply_7 (Multiply)          (None, 32, 32, 184)  0           ['expanded_conv_9/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_10[0][0]']
#
#  expanded_conv_9/depthwise (Dep  (None, 32, 32, 184)  1656       ['multiply_7[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_9/depthwise/Batc  (None, 32, 32, 184)  736        ['expanded_conv_9/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_11 (TFOpL  (None, 32, 32, 184)  0          ['expanded_conv_9/depthwise/Batch
#  ambda)                                                          Norm[0][0]']
#
#  re_lu_22 (ReLU)                (None, 32, 32, 184)  0           ['tf.__operators__.add_11[0][0]']
#
#  tf.math.multiply_11 (TFOpLambd  (None, 32, 32, 184)  0          ['re_lu_22[0][0]']
#  a)
#
#  multiply_8 (Multiply)          (None, 32, 32, 184)  0           ['expanded_conv_9/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_11[0][0]']
#
#  expanded_conv_9/project (Conv2  (None, 32, 32, 80)  14720       ['multiply_8[0][0]']
#  D)
#
#  expanded_conv_9/project/BatchN  (None, 32, 32, 80)  320         ['expanded_conv_9/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_9/Add (Add)      (None, 32, 32, 80)   0           ['expanded_conv_8/Add[0][0]',
#                                                                   'expanded_conv_9/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_10/expand (Conv2  (None, 32, 32, 480)  38400      ['expanded_conv_9/Add[0][0]']
#  D)
#
#  expanded_conv_10/expand/BatchN  (None, 32, 32, 480)  1920       ['expanded_conv_10/expand[0][0]']
#  orm (BatchNormalization)
#
#  tf.__operators__.add_12 (TFOpL  (None, 32, 32, 480)  0          ['expanded_conv_10/expand/BatchNo
#  ambda)                                                          rm[0][0]']
#
#  re_lu_23 (ReLU)                (None, 32, 32, 480)  0           ['tf.__operators__.add_12[0][0]']
#
#  tf.math.multiply_12 (TFOpLambd  (None, 32, 32, 480)  0          ['re_lu_23[0][0]']
#  a)
#
#  multiply_9 (Multiply)          (None, 32, 32, 480)  0           ['expanded_conv_10/expand/BatchNo
#                                                                  rm[0][0]',
#                                                                   'tf.math.multiply_12[0][0]']
#
#  expanded_conv_10/depthwise (De  (None, 32, 32, 480)  4320       ['multiply_9[0][0]']
#  pthwiseConv2D)
#
#  expanded_conv_10/depthwise/Bat  (None, 32, 32, 480)  1920       ['expanded_conv_10/depthwise[0][0
#  chNorm (BatchNormalization)                                     ]']
#
#  tf.__operators__.add_13 (TFOpL  (None, 32, 32, 480)  0          ['expanded_conv_10/depthwise/Batc
#  ambda)                                                          hNorm[0][0]']
#
#  re_lu_24 (ReLU)                (None, 32, 32, 480)  0           ['tf.__operators__.add_13[0][0]']
#
#  tf.math.multiply_13 (TFOpLambd  (None, 32, 32, 480)  0          ['re_lu_24[0][0]']
#  a)
#
#  multiply_10 (Multiply)         (None, 32, 32, 480)  0           ['expanded_conv_10/depthwise/Batc
#                                                                  hNorm[0][0]',
#                                                                   'tf.math.multiply_13[0][0]']
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 480)   0           ['multiply_10[0][0]']
#  e/AvgPool (GlobalAveragePoolin
#  g2D)
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 120)   57720       ['expanded_conv_10/squeeze_excite
#  e/Conv (Conv2D)                                                 /AvgPool[0][0]']
#
# ...
#
#  expanded_conv_13/expand (Conv2  (None, 16, 16, 960)  153600     ['expanded_conv_12/project/BatchN
#  D)                                                              orm[0][0]']
#
#  expanded_conv_13/expand/BatchN  (None, 16, 16, 960)  3840       ['expanded_conv_13/expand[0][0]']
#  orm (BatchNormalization)
#
#  tf.__operators__.add_21 (TFOpL  (None, 16, 16, 960)  0          ['expanded_conv_13/expand/BatchNo
#  ambda)                                                          rm[0][0]']
#
#  re_lu_32 (ReLU)                (None, 16, 16, 960)  0           ['tf.__operators__.add_21[0][0]']
#
#  tf.math.multiply_21 (TFOpLambd  (None, 16, 16, 960)  0          ['re_lu_32[0][0]']
#  a)
#
#  multiply_15 (Multiply)         (None, 16, 16, 960)  0           ['expanded_conv_13/expand/BatchNo
#                                                                  rm[0][0]',
#                                                                   'tf.math.multiply_21[0][0]']
#
#  expanded_conv_13/depthwise (De  (None, 16, 16, 960)  24000      ['multiply_15[0][0]']
#  pthwiseConv2D)
#
#  expanded_conv_13/depthwise/Bat  (None, 16, 16, 960)  3840       ['expanded_conv_13/depthwise[0][0
#  chNorm (BatchNormalization)                                     ]']
#
#  tf.__operators__.add_22 (TFOpL  (None, 16, 16, 960)  0          ['expanded_conv_13/depthwise/Batc
#  ambda)                                                          hNorm[0][0]']
#
#  re_lu_33 (ReLU)                (None, 16, 16, 960)  0           ['tf.__operators__.add_22[0][0]']
#
#  tf.math.multiply_22 (TFOpLambd  (None, 16, 16, 960)  0          ['re_lu_33[0][0]']
#  a)
#
#  multiply_16 (Multiply)         (None, 16, 16, 960)  0           ['expanded_conv_13/depthwise/Batc
#                                                                  hNorm[0][0]',
#                                                                   'tf.math.multiply_22[0][0]']
#
#  expanded_conv_13/squeeze_excit  (None, 1, 1, 960)   0           ['multiply_16[0][0]']
#  e/AvgPool (GlobalAveragePoolin
#  g2D)
#
#  expanded_conv_13/squeeze_excit  (None, 1, 1, 240)   230640      ['expanded_conv_13/squeeze_excite
#  e/Conv (Conv2D)                                                 /AvgPool[0][0]']
#
#  expanded_conv_13/squeeze_excit  (None, 1, 1, 240)   0           ['expanded_conv_13/squeeze_excite
#  e/Relu (ReLU)                                                   /Conv[0][0]']
#
#  expanded_conv_13/squeeze_excit  (None, 1, 1, 960)   231360      ['expanded_conv_13/squeeze_excite
#  e/Conv_1 (Conv2D)                                               /Relu[0][0]']
#
#  tf.__operators__.add_23 (TFOpL  (None, 1, 1, 960)   0           ['expanded_conv_13/squeeze_excite
#  ambda)                                                          /Conv_1[0][0]']
#
#  re_lu_34 (ReLU)                (None, 1, 1, 960)    0           ['tf.__operators__.add_23[0][0]']
#
#  tf.math.multiply_23 (TFOpLambd  (None, 1, 1, 960)   0           ['re_lu_34[0][0]']
#  a)
#
#  expanded_conv_13/squeeze_excit  (None, 16, 16, 960)  0          ['multiply_16[0][0]',
#  e/Mul (Multiply)                                                 'tf.math.multiply_23[0][0]']
#
#  expanded_conv_13/project (Conv  (None, 16, 16, 160)  153600     ['expanded_conv_13/squeeze_excite
#  2D)                                                             /Mul[0][0]']
#
#  expanded_conv_13/project/Batch  (None, 16, 16, 160)  640        ['expanded_conv_13/project[0][0]'
#  Norm (BatchNormalization)                                       ]
#
#  expanded_conv_13/Add (Add)     (None, 16, 16, 160)  0           ['expanded_conv_12/project/BatchN
#                                                                  orm[0][0]',
#                                                                   'expanded_conv_13/project/BatchN
#                                                                  orm[0][0]']
#
#  expanded_conv_14/expand (Conv2  (None, 16, 16, 960)  153600     ['expanded_conv_13/Add[0][0]']
#  D)
#
#  expanded_conv_14/expand/BatchN  (None, 16, 16, 960)  3840       ['expanded_conv_14/expand[0][0]']
#  orm (BatchNormalization)
#
#  tf.__operators__.add_24 (TFOpL  (None, 16, 16, 960)  0          ['expanded_conv_14/expand/BatchNo
#  ambda)                                                          rm[0][0]']
#
#  re_lu_35 (ReLU)                (None, 16, 16, 960)  0           ['tf.__operators__.add_24[0][0]']
#
#  tf.math.multiply_24 (TFOpLambd  (None, 16, 16, 960)  0          ['re_lu_35[0][0]']
#  a)
#
#  multiply_17 (Multiply)         (None, 16, 16, 960)  0           ['expanded_conv_14/expand/BatchNo
#                                                                  rm[0][0]',
#                                                                   'tf.math.multiply_24[0][0]']
#
#  expanded_conv_14/depthwise (De  (None, 16, 16, 960)  24000      ['multiply_17[0][0]']
#  pthwiseConv2D)
#
#  expanded_conv_14/depthwise/Bat  (None, 16, 16, 960)  3840       ['expanded_conv_14/depthwise[0][0
#  chNorm (BatchNormalization)                                     ]']
#
#  tf.__operators__.add_25 (TFOpL  (None, 16, 16, 960)  0          ['expanded_conv_14/depthwise/Batc
#  ambda)                                                          hNorm[0][0]']
#
#  re_lu_36 (ReLU)                (None, 16, 16, 960)  0           ['tf.__operators__.add_25[0][0]']
#
#  tf.math.multiply_25 (TFOpLambd  (None, 16, 16, 960)  0          ['re_lu_36[0][0]']
#  a)
#
#  multiply_18 (Multiply)         (None, 16, 16, 960)  0           ['expanded_conv_14/depthwise/Batc
#                                                                  hNorm[0][0]',
#                                                                   'tf.math.multiply_25[0][0]']
#
#  expanded_conv_14/squeeze_excit  (None, 1, 1, 960)   0           ['multiply_18[0][0]']
#  e/AvgPool (GlobalAveragePoolin
#  g2D)
#
#  expanded_conv_14/squeeze_excit  (None, 1, 1, 240)   230640      ['expanded_conv_14/squeeze_excite
#  e/Conv (Conv2D)                                                 /AvgPool[0][0]']
#
#  expanded_conv_14/squeeze_excit  (None, 1, 1, 240)   0           ['expanded_conv_14/squeeze_excite
#  e/Relu (ReLU)                                                   /Conv[0][0]']
#
#  expanded_conv_14/squeeze_excit  (None, 1, 1, 960)   231360      ['expanded_conv_14/squeeze_excite
#  e/Conv_1 (Conv2D)                                               /Relu[0][0]']
#
#  tf.__operators__.add_26 (TFOpL  (None, 1, 1, 960)   0           ['expanded_conv_14/squeeze_excite
#  ambda)                                                          /Conv_1[0][0]']
#
#  re_lu_37 (ReLU)                (None, 1, 1, 960)    0           ['tf.__operators__.add_26[0][0]']
#
#  tf.math.multiply_26 (TFOpLambd  (None, 1, 1, 960)   0           ['re_lu_37[0][0]']
#  a)
#
#  expanded_conv_14/squeeze_excit  (None, 16, 16, 960)  0          ['multiply_18[0][0]',
#  e/Mul (Multiply)                                                 'tf.math.multiply_26[0][0]']
#
#  expanded_conv_14/project (Conv  (None, 16, 16, 160)  153600     ['expanded_conv_14/squeeze_excite
#  2D)                                                             /Mul[0][0]']
#
#  expanded_conv_14/project/Batch  (None, 16, 16, 160)  640        ['expanded_conv_14/project[0][0]'
#  Norm (BatchNormalization)                                       ]
#
#  expanded_conv_14/Add (Add)     (None, 16, 16, 160)  0           ['expanded_conv_13/Add[0][0]',
#                                                                   'expanded_conv_14/project/BatchN
#                                                                  orm[0][0]']
#
#  Conv_1 (Conv2D)                (None, 16, 16, 960)  153600      ['expanded_conv_14/Add[0][0]']
#
#  Conv_1/BatchNorm (BatchNormali  (None, 16, 16, 960)  3840       ['Conv_1[0][0]']
#  zation)
#
#  tf.__operators__.add_27 (TFOpL  (None, 16, 16, 960)  0          ['Conv_1/BatchNorm[0][0]']
#  ambda)
#
#  re_lu_38 (ReLU)                (None, 16, 16, 960)  0           ['tf.__operators__.add_27[0][0]']
#
#  tf.math.multiply_27 (TFOpLambd  (None, 16, 16, 960)  0          ['re_lu_38[0][0]']
#  a)
#
#  multiply_19 (Multiply)         (None, 16, 16, 960)  0           ['Conv_1/BatchNorm[0][0]',
#                                                                   'tf.math.multiply_27[0][0]']
#
# ==================================================================================================
# Total params: 2,996,352
# Trainable params: 2,971,952
# Non-trainable params: 24,400
# __________________________________________________________________________________________________

# %%
MobileNetV3Large_model.trainable = False

preprocess_input = tf.keras.applications.mobilenet_v3.preprocess_input

image_batch, label_batch = next(iter(bn_train))
feature_batch = MobileNetV3Large_model(image_batch)
print(feature_batch.shape)
# Out:
# (32, 16, 16, 960)

# %%
global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
feature_batch_average = global_average_layer(feature_batch)
print(feature_batch_average.shape)
# Out:
# (32, 960)

# %%
prediction_layer = tf.keras.layers.Dense(3)
prediction_batch = prediction_layer(feature_batch_average)
print(f' The size of the predicted value for a given batch = {prediction_batch.shape}')
# Out:
#  The size of the predicted value for a given batch = (32, 3)

# %%
inputs = tf.keras.Input(shape = IMG_SHAPE)
x = data_aug(inputs)
x = preprocess_input(x)
x = MobileNetV3Large_model(x, training=False)
x = global_average_layer(x)
x = tf.keras.layers.Dropout(0.2)(x)
outputs = prediction_layer(x)
model = tf.keras.Model(inputs, outputs)

# %%
learning_rate = 0.0001
model.compile(optimizer=tf.keras.optimizers.Adam(lr=learning_rate),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
# Out:
# C:\Anaconda\envs\masters\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
# %%time
callback = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience= 3)
epochs= 20
history = model.fit(
  bn_train,
  validation_data=bn_validation,
  epochs=epochs,
  callbacks=[callback], verbose = 1
)
# Out:
# Epoch 1/20
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# 33/33 [==============================] - 69s 2s/step - loss: 1.2768 - accuracy: 0.3375 - val_loss: 1.1530 - val_accuracy: 0.3308
# Epoch 2/20
# 33/33 [==============================] - 56s 2s/step - loss: 1.1813 - accuracy: 0.3346 - val_loss: 1.1052 - val_accuracy: 0.3308
# Epoch 3/20
# 33/33 [==============================] - 55s 2s/step - loss: 1.1418 - accuracy: 0.3559 - val_loss: 1.0998 - val_accuracy: 0.2782
# Epoch 4/20
# 33/33 [==============================] - 55s 2s/step - loss: 1.1527 - accuracy: 0.3269 - val_loss: 1.0994 - val_accuracy: 0.3910
# Epoch 5/20
# 33/33 [==============================] - 53s 2s/step - loss: 1.1456 - accuracy: 0.3279 - val_loss: 1.0993 - val_accuracy: 0.3459
# Epoch 6/20
# 33/33 [==============================] - 53s 2s/step - loss: 1.1360 - accuracy: 0.3569 - val_loss: 1.0991 - val_accuracy: 0.3759
# Epoch 7/20
# 33/33 [==============================] - 55s 2s/step - loss: 1.1494 - accuracy: 0.3162 - val_loss: 1.0988 - val_accuracy: 0.3008
# CPU times: total: 1h 32min 55s
# Wall time: 6min 35s

# %%
train_history = pd.DataFrame(history.history)
train_history['epoch'] = history.epoch
#Plot train loss
sns.lineplot(x='epoch', y ='loss', data =train_history)
#Plot validation loss
sns.lineplot(x='epoch', y ='val_loss', data =train_history)
#Add legends
plt.legend(labels=['train_loss', 'val_loss'])

# %%
sns.lineplot(x='epoch', y ='accuracy', data =train_history)
#Plot validation loss
sns.lineplot(x='epoch', y ='val_accuracy', data =train_history)
#Add legends
plt.legend(labels=['train_accuracy', 'val_accuracy'])

# %%
predictions = model.predict(bn_test)
# Compute the softmax, i.e., obtain the probabilities of each class
score = tf.nn.softmax(predictions)
# Out:
# 4/4 [==============================] - 6s 1s/step
